# %% [markdown]
# # Aprendendo R

# %% [markdown]
# ## Variáveis

# %% [markdown]
# <strong>Formas de criar variáveis em R <br>Operador de atribuição:</strong> <-

# %%
# Formato1: mais usual
a <- 10

# Formato2
20 -> b

# Formato3
c = 30

# %% [markdown]
# ## Operações

# %% [markdown]
# ![operadores aritiméticos](attachment:image.png)

# %%
# teste
resultado <- a * b + c / a - c^2
resultado
# Out:
# [1] -697
